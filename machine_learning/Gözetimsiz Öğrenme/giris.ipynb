# %% [markdown]
# ![Ekran Resmi 2022-02-16 23.40.05.png](attachment:f08135d9-e1f2-4464-bec2-8cd1337c7e83.png)

# %% [markdown]
# ***Makine öğrenmesi modellerinde, bağımlı değişkenin elimizde olmadığı durumlarda gözlem birimlerinin bir şekilde anlamlı hale getirilme çabası olarak nitelendirebileceğimiz bir yöntemdir.***

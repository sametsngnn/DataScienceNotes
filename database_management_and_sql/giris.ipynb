# %% [markdown]
# ![Ekran Resmi 2022-02-19 05.17.13.png](attachment:9bee19fe-21a7-4c83-ace3-a0e743ad1337.png)

# %% [markdown]
# ![Ekran Resmi 2022-02-19 05.20.20.png](attachment:754f271f-1602-4248-b6ff-728663219d2d.png)

# %% [markdown]
# ***SQL bir sorgu dilidir. Programlama dili değildir.***
#
# ***Veritabanı yönetim sistemleri ise bu SQL sorgu dilini veya çok küçük varyanslarla farklılaşan versiyonlarını kullanan veritabanı yönetim sistemleridir.***
